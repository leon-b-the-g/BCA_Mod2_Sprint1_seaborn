# %%
import matplotlib.pyplot as plt

import seaborn as sns 



import numpy as np


import pandas as pd

# %%
red_base_df = pd.read_csv("wine_data/winequality-red.csv", sep = ";")

#red_base_df.head(5)

white_base_df = pd.read_csv("wine_data/winequality-white.csv", sep = ";")

white_base_df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
#Checking df shapes 
#red_base_df.info()
#red_base_df.isna().count()

#white_base_df.info()
red_base_df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#combine dfs 

allwine_base_df = pd.concat([red_base_df.describe(), white_base_df.describe()], axis=1, keys=["red_wine", "white_wine"])
allwine_base_df["white_wine"].head(10)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
allwine_base_df["red_wine"].head(10)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
###Observations
#1. higher mean sulfates and mean volatile acidity in red wine than white wine
#2. mean pH is slightly lower in white wine (3.1 vs 3.3)
#3. mean free sulfur dioxides and total sulfur dioxide is higher in white wine (white: 35.3 free and 138.46 in total, vs. red: 15.87 free and only 46.47 total)
#4. mean chlorides is 2x higher in red wine (red: 0.08 vs white: 0.04)
#5. mean sugar in white wine significantly higher (white: 6.4 vs red: 2.5)
#6. mean fixed acidity higher in red whine (red: 8.32 vs white 6.85)

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_base_df['quality_label'] = red_base_df['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high') 

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_base_df['quality_label'] = pd.Categorical(red_base_df['quality_label'],
categories=['low', 'medium', 'high'])

red_base_df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality quality_label
# 0      9.4        5           low
# ...

# %%
white_base_df["quality_label"] = white_base_df['quality'].apply(lambda value: "low"
                                                                if value <= 4 else "medium"
                                                                if value <= 7 else "high") # great example of .apply(lamda)


white_base_df["quality_label"] = pd.Categorical(white_base_df["quality_label"], categories = ["low","medium","high"])

white_base_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
#  12  quality_label         4898 non-null   category
# dtypes: category(1), float64(11), int64(1)
# memory usage: 464.2 KB

# %%
stats_df = pd.concat([red_base_df.describe(),white_base_df.describe()], axis = 1, keys =["red_wine","white_wine"])
stats_df["red_wine"].head(10)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
stats_df["white_wine"].head(10)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
#Plotting a pie chart for the data instances of red and white 
sizes = [red_base_df.value_counts().sum(),white_base_df.value_counts().sum()]
labels = ["Red Wine", "White wine"]

fig, ax = plt.subplots()
ax.pie(sizes,labels = labels, autopct='%1.1f%%', pctdistance=1.25, labeldistance=.4, colors=['red', 'rosybrown'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2901b7f0a40>,
# ...
#  [Text(0.2862749236173353, 0.2793683376975437, 'Red Wine'),
#   Text(-0.2862749366955108, -0.27936832429604697, 'White wine')],
#  [Text(0.8946091363041728, 0.8730260553048241, '24.6%'),
#   Text(-0.8946091771734712, -0.8730260134251467, '75.4%')])

# %%
#histoplot to make two histograms for the quality_label column of white and red
#quali_red = red_base_df.loc[:,["quality_label"]].value_counts()

quali_red = red_base_df["quality_label"].value_counts()

proper_name_red = quali_red.rename("Red Wine Quality")



quali_white = white_base_df["quality_label"].value_counts()
proper_name_white = quali_white.rename("White Wine Quality")
#white_series = quali_white.rename(columns={quali_red.columns[0]:"White Wine Quality"})

#Concat and renaming axis 
qual_label_df = pd.concat([proper_name_red,proper_name_white], axis = 1, names= redwhite)

#qual_label_df.rename({qual_label_df[0]:"Red Wine Quality", qual_label_df[1]:"White Wine Quality"})
#qual_label_df = qual_label_df.rename(columns={qual_label_df.columns[0]:"White Wine Quality",qual_label_df.columns[1]:"Red Wine Quality"})

#qual_label_df.head(5)

#red_series.head(5)
#plot with seaborn

#sns.histplot(data = qual_label_df, x)

quali_red.head(10)
# Out:
# quality_label
# medium    837
# low       744
# high       18
# Name: count, dtype: int64
